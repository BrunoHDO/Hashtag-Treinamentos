# %% [markdown]
# # Listas
#
# <span style="color: red;"><b>Todos os exercícios são feitos partindo-se do pressuposto de que todas as entradas são dadas de forma correta. Casos limite não mencionados no enunciado não são abordados porque não fazem parte do exercício.</b></span>

# %% [markdown]
# #### 1. Faça um Programa que leia as vendas dos vendedores, mostre a venda de cada vendedor com o seu nome e a média de vendas.

# %%
vendas = [1000, 1500, 1200, 1300]
vendedores = ["Fulano", "Beltrano", "Ciclano", "Lira"]

for i in range(len(vendas)):
    porcentagem_venda = vendas[i] / sum(vendas)
    print(f'{vendedores[i]}, vendeu {vendas[i]}. O vendedor teve {porcentagem_venda:.1%}')

    media_venda = sum(vendas) / len(vendas)
print(f'A media de vendas foi: {media_venda}')
# Out:
# Fulano, vendeu 1000. O vendedor teve 20.0%
# Beltrano, vendeu 1500. O vendedor teve 30.0%
# Ciclano, vendeu 1200. O vendedor teve 24.0%
# Lira, vendeu 1300. O vendedor teve 26.0%
# A media de vendas foi: 1250.0

# %% [markdown]
# #### 2. Faça um Programa que crie uma lista com as médias de cada aluno, imprima as médias de cada aluno e a quantidade de alunos com média maior que 7.

# %%
alunos = ["José", "Joana", "Maria", "Carla", "Mauricio", "Andre", "Tiago", "Enzo", "Amanda", "Alessandra"]
notas = [
    [10, 9, 8, 8],
    [9, 7, 6, 4],
    [10, 10, 10, 10],
    [5, 3, 10, 9],
    [7, 6, 6, 6],
    [7, 7, 8, 7],
    [7, 7, 7, 9],
    [8, 5, 6, 7],
    [10, 9, 7, 4],
    [10, 1, 3, 3],
]

medias = []

for i in range(len(notas)):
    media = sum(notas[i]) / len(notas[i])
    medias.append(media)
    print(f'O Aluno(a): {alunos[i]}, teve media {media}')

contador = 0
for media in medias:
    if media >= 7:
        contador += 1
        
print(f'Tiveram {contador} que ficarm com a media igual ou acima de 7')
# Out:
# O Aluno(a): José, teve media 8.75
# O Aluno(a): Joana, teve media 6.5
# O Aluno(a): Maria, teve media 10.0
# O Aluno(a): Carla, teve media 6.75
# O Aluno(a): Mauricio, teve media 6.25
# O Aluno(a): Andre, teve media 7.25
# O Aluno(a): Tiago, teve media 7.5
# O Aluno(a): Enzo, teve media 6.5
# O Aluno(a): Amanda, teve media 7.5
# O Aluno(a): Alessandra, teve media 4.25
# Tiveram 5 que ficarm com a media igual ou acima de 7

# %% [markdown]
# #### 3. Foram anotadas as idades e salários de 30 funcionários. Faça um programa que determine quantos funcionários com mais de 25 anos possuem salário inferior à média de todos os salários.

# %%
idades = [35,32,50,33,48,50,33,48,22,49,35,38,20,47,49,48,34,21,48,44,48,30,25,42,42,23,25,23,38,35]
salarios = [3739,2219,3554,3978,4014,3270,4792,3879,2981,2384,4826,2460,3680,4318,1872,1770,4640,3929,3295,1729,3965,4267,4007,1916,2987,2943,3852,4543,2055,1730]

media_salario = sum(salarios) / len(salarios)
print(media_salario)

contador = 0
for i, idade in enumerate(idades):
    if idade > 25 and salarios[i] < media_salario:
        contador += 1

print(f'São {contador} funcionarios com idade acima ou igual a 25 anos que recebem menos da media {media_salario}')
# Out:
# 3319.8
# São 12 funcionarios com idade acima ou igual a 25 anos que recebem menos da media 3319.8

# %% [markdown]
# #### 4.Em quais meses a média de temperatura foi maior do que a média nacional?

# %%
meses = [
    'Janeiro',
    'Fevereiro',
    'Março',
    'Abril',
    'Maio',
    'Junho',
    'Julho',
    'Agosto',
    'Setembro',
    'Outubro',
    'Novembro',
    'Dezembro'
]

temperaturas = [30, 29, 28, 28, 25, 26, 20, 21, 19, 25, 27, 32]

media_temperatura = sum(temperaturas) / len(temperaturas)
print(f'A média anual foi de {int(media_temperatura)}°C')

for i, mes in enumerate(meses):
    if temperaturas[i] > media_temperatura:
        print(f'{mes} com {temperaturas[i]}°C')
# Out:
# A média anual foi de 25°C
# Janeiro com 30°C
# Fevereiro com 29°C
# Março com 28°C
# Abril com 28°C
# Junho com 26°C
# Novembro com 27°C
# Dezembro com 32°C

# %% [markdown]
# #### 5. As Organizações Tabajara resolveram dar um abono aos seus colaboradores em reconhecimento ao bom resultado alcançado durante o ano que passou. Para isto contratou você para desenvolver a aplicação que servirá como uma projeção de quanto será gasto com o pagamento deste abono.
# <pre>Após reuniões envolvendo a diretoria executiva, a diretoria financeira e os representantes do sindicato laboral, chegou-se a seguinte forma de cálculo:
# . Cada funcionário receberá o equivalente a 20% do seu salário bruto de dezembro;
# . O piso do abono será de 100 reais, isto é, aqueles funcionários cujo salário for muito baixo, recebem este valor mínimo;
#
# Neste momento, não se deve ter nenhuma preocupação com colaboradores com tempo menor de casa, descontos, impostos ou outras particularidades. O programa deverá calcular o valor do abono concedido a cada colaborador, de acordo com a regra definida acima. Ao final, o programa deverá apresentar:</pre>
# <pre>
# O salário de cada funcionário, juntamente com o valor do abono;
# O número total de funcionário processados;
# O valor total a ser gasto com o pagamento do abono;
# O número de funcionário que receberá o valor mínimo de 100 reais;
# O maior valor pago como abono; A tela abaixo é um exemplo de execução do programa, apenas para fins ilustrativos.
# <pre>
# Projeção de Gastos com Abono
# ============================
#
# Salário: 1000
# Salário: 300
# Salário: 500
# Salário: 100
# Salário: 4500
# Salário: 0
#
# Salário    - Abono
# R$ 1000.00 - R$  200.00
# R$  300.00 - R$  100.00
# R$  500.00 - R$  100.00
# R$  100.00 - R$  100.00
# R$ 4500.00 - R$  900.00
#
# Foram processados 5 colaboradores
# Total gasto com abonos: R$ 1400.00
# Valor mínimo pago a 3 colaboradores
# Maior valor de abono pago: R$ 900.00

# %%
lista_salarios = [1000, 300, 500, 200, 1500, 3000, 3400, 5000, 7000, 2000, 600, 800, 250, 1500, 20000]
abonos = []

#O salário de cada funcionário, juntamente com o valor do abono;
print('Salario - Abono')
conta_minimo = 0
for salario in lista_salarios:
    abono = salario * 0.2
    if abono < 100:
        abono = 100
    abonos.append(abono)
    if abono == 100:
        conta_minimo += 1
    print(f'R$ {salario} - R$ {abono}')

#O número total de funcionário processados;
total_funcionarios = len(lista_salarios)
print('Foram processados', total_funcionarios, 'colaboradores')
#O valor total a ser gasto com o pagamento do abono;
total_abono = sum(abonos)
print(f'Total gasto com abonos: R$ {total_abono:.2f}')
#O número de funcionário que receberá o valor mínimo de 100 reais;
print('Valor mínimo pago a', conta_minimo, 'colaboradores')
#O maior valor pago como abono; A tela abaixo é um exemplo de execução do programa, apenas para fins ilustrativos.
abono_max = max(abonos)
print(f'Maior valor de abono pago: R$ {abono_max:.2f}')
# Out:
# Salario - Abono
# R$ 1000 - R$ 200.0
# R$ 300 - R$ 100
# R$ 500 - R$ 100.0
# R$ 200 - R$ 100
# R$ 1500 - R$ 300.0
# R$ 3000 - R$ 600.0
# R$ 3400 - R$ 680.0
# R$ 5000 - R$ 1000.0
# R$ 7000 - R$ 1400.0
# R$ 2000 - R$ 400.0
# R$ 600 - R$ 120.0
# R$ 800 - R$ 160.0
# R$ 250 - R$ 100
# R$ 1500 - R$ 300.0
# R$ 20000 - R$ 4000.0
# Foram processados 15 colaboradores
# Total gasto com abonos: R$ 9560.00
# Valor mínimo pago a 4 colaboradores
# Maior valor de abono pago: R$ 4000.00

# %% [markdown]
# #### 6. Faça um programa que carregue uma lista com os modelos de cinco carros (exemplo de modelos: FUSCA, GOL, VECTRA etc). Carregue uma outra lista com o consumo desses carros, isto é, quantos quilômetros cada um desses carros faz com um litro de combustível. Calcule e mostre:
# <pre>
# a. O modelo do carro mais econômico;
# b. Quantos litros de combustível cada um dos carros cadastrados consome para percorrer uma distância de 1000 quilômetros e quanto isto custará, considerando um que a gasolina custe R$ 2,25 o litro. Abaixo segue uma tela de exemplo. O disposição das informações deve ser o mais próxima possível ao exemplo. Os dados são fictícios e podem mudar a cada execução do programa.</pre>
# ```
# Comparativo de Consumo de Combustível
#
# Veículo 1
# Nome: fusca
# Km por litro: 7
# Veículo 2
# Nome: gol
# Km por litro: 10
# Veículo 3
# Nome: uno
# Km por litro: 12.5
# Veículo 4
# Nome: Vectra
# Km por litro: 9
# Veículo 5
# Nome: Peugeout
# Km por litro: 14.5
#
# Relatório Final
#  1 - fusca           -    7.0 -  142.9 litros - R$ 321.43
#  2 - gol             -   10.0 -  100.0 litros - R$ 225.00
#  3 - uno             -   12.5 -   80.0 litros - R$ 180.00
#  4 - vectra          -    9.0 -  111.1 litros - R$ 250.00
#  5 - peugeout        -   14.5 -   69.0 litros - R$ 155.17
# O menor consumo é do peugeout.
# ```

# %%
print('Comparativo de Consumo de Combustível')
veiculos = ['fusca','gol', 'uno', 'vectra', 'peugeot']
autonomias = [7, 10, 12.5, 9, 14.5]

print('Relatório Final')
for i, autonomia in enumerate(autonomias):
    consumo = 1000 / autonomias[i]
    valor = consumo * 2.25
    print(f' {i+1} - Carro: {veiculos[i]} - Autonomia: {autonomia:.1f}L por Km - 1000Km: {consumo:.2f}Litros - R${valor:.2f}')

maior = max(autonomias)
i = autonomias.index(maior)
print('O menor consumo é do', veiculos[i])
# Out:
# Comparativo de Consumo de Combustível
# Relatório Final
#  1 - Carro: fusca - Autonomia: 7.0L por Km - 1000Km: 142.86Litros - R$321.43
#  2 - Carro: gol - Autonomia: 10.0L por Km - 1000Km: 100.00Litros - R$225.00
#  3 - Carro: uno - Autonomia: 12.5L por Km - 1000Km: 80.00Litros - R$180.00
#  4 - Carro: vectra - Autonomia: 9.0L por Km - 1000Km: 111.11Litros - R$250.00
#  5 - Carro: peugeot - Autonomia: 14.5L por Km - 1000Km: 68.97Litros - R$155.17
# O menor consumo é do peugeot

# %%
# Listas com modelos de carros e seus consumos
modelos_carros = ["FUSCA", "GOL", "UNO", "VECTRA", "PEUGEOUT"]
consumo_carros = [7, 10, 12.5, 9, 14.5]

# Encontra o índice do carro mais econômico
indice_carro_mais_economico = consumo_carros.index(max(consumo_carros))

# Custo estimado da gasolina por litro
custo_gasolina_por_litro = 2.25

# Imprime a lista de carros e seus consumos
print("Comparativo de Consumo de Combustível")
for i in range(len(modelos_carros)):
    print(f"Veículo {i + 1}\nNome: {modelos_carros[i]}\nKm por litro: {consumo_carros[i]}")

# Calcula e imprime o consumo para 1000 quilômetros e o custo estimado
print("\nRelatório Final")
for i in range(len(modelos_carros)):
    consumo_1000_km = 1000 / consumo_carros[i]
    custo_estimado = consumo_1000_km * custo_gasolina_por_litro
    print(f"{i + 1} - {modelos_carros[i]:<15} - {consumo_carros[i]:>5.1f} - {consumo_1000_km:>6.1f} litros - R$ {custo_estimado:.2f}")

# Imprime o modelo do carro mais econômico
print(f"O menor consumo é do {modelos_carros[indice_carro_mais_economico].lower()}.")
# Out:
# Comparativo de Consumo de Combustível
# Veículo 1
# Nome: FUSCA
# Km por litro: 7
# Veículo 2
# Nome: GOL
# Km por litro: 10
# Veículo 3
# Nome: UNO
# Km por litro: 12.5
# Veículo 4
# Nome: VECTRA
# Km por litro: 9
# Veículo 5
# Nome: PEUGEOUT
# Km por litro: 14.5
#
# Relatório Final
# 1 - FUSCA           -   7.0 -  142.9 litros - R$ 321.43
# 2 - GOL             -  10.0 -  100.0 litros - R$ 225.00
# 3 - UNO             -  12.5 -   80.0 litros - R$ 180.00
# 4 - VECTRA          -   9.0 -  111.1 litros - R$ 250.00
# 5 - PEUGEOUT        -  14.5 -   69.0 litros - R$ 155.17
# O menor consumo é do peugeout.

# %% [markdown]
# #### 7. Uma empresa paga seus vendedores com base em comissões. O vendedor recebe \\$200 por semana mais 9 por cento de suas vendas brutas daquela semana. Por exemplo, um vendedor que teve vendas brutas de \\$3000 em uma semana recebe \\$200 mais 9 por cento de \\$3000, ou seja, um total de \\$470. Escreva um programa (usando um array de contadores) que determine quantos vendedores receberam salários nos seguintes intervalos de valores:
# <pre>
# $200 - $299
# $300 - $399
# $400 - $499
# $500 - $599
# $600 - $699
# $700 - $799
# $800 - $899
# $900 - $999
# $1000 em diante
# </pre>
#
# Existem várias formas de fazer. Faça primeiro da forma que parecer mais intuitiva para você.
#
# Em seguida, caso queira um desafio:
# Desafio: Crie uma forma para chegar na posição da lista a partir do salário, sem fazer vários ifs aninhados.

# %%
vendas = [1000, 2000, 3000, 4000, 5000, 6000, 5500, 4500, 3600]
salarios = []
comissoes = []

for venda in vendas:
    total_comissao = 200 + (venda * 0.09)
    comissoes.append(total_comissao)
    salario = venda + total_comissao
    salarios.append(salario)

print(f'O total das comissões foi de R${sum(comissoes)}. Ficando dispostas da seguinte forma:')
print(comissoes)
print('-----------------------------------------------------------------------------')
print(f'O salário bruto total somando as comissões foi de R${sum(salarios)}. Ficando dispostos da seguinte forma:')
print(salarios)
# Out:
# O total das comissões foi de R$4914.0. Ficando dispostas da seguinte forma:
# [290.0, 380.0, 470.0, 560.0, 650.0, 740.0, 695.0, 605.0, 524.0]
# -----------------------------------------------------------------------------
# O salário bruto total somando as comissões foi de R$39514.0. Ficando dispostos da seguinte forma:
# [1290.0, 2380.0, 3470.0, 4560.0, 5650.0, 6740.0, 6195.0, 5105.0, 4124.0]
